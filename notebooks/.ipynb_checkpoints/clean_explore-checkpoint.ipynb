# %%
import pandas as pd
import numpy as np
import json

# %%
with open('../data/train.json') as f:
    tr = json.load(f)

# %%
cuisines = set([])

for recipe in tr:
    cuisines.add(recipe['cuisine'])

# %%
cuisines = list(cuisines)

# %%
for cuisine in cuisines:
    print(cuisine + ' = set([])')
# Out:
# italian = set([])
# greek = set([])
# indian = set([])
# brazilian = set([])
# french = set([])
# irish = set([])
# chinese = set([])
# thai = set([])
# russian = set([])
# korean = set([])
# southern_us = set([])
# filipino = set([])
# vietnamese = set([])
# japanese = set([])
# cajun_creole = set([])
# moroccan = set([])
# british = set([])
# jamaican = set([])
# spanish = set([])
# mexican = set([])

# %%
italian = set([])
greek = set([])
indian = set([])
brazilian = set([])
french = set([])
irish = set([])
chinese = set([])
thai = set([])
russian = set([])
korean = set([])
southern_us = set([])
filipino = set([])
vietnamese = set([])
japanese = set([])
cajun_creole = set([])
moroccan = set([])
british = set([])
jamaican = set([])
spanish = set([])
mexican = set([])

# %%
for cuisine in cuisines:
    print("    if recipe['cuisine'] == '" + cuisine + "':")
    print("        for ingredient in recipe['ingredients']:")
    print("             " + cuisine + ".add(ingredient)")
# Out:
#     if recipe['cuisine'] == 'italian':
#         for ingredient in recipe['ingredients']:
#              italian.add(ingredient)
#     if recipe['cuisine'] == 'greek':
#         for ingredient in recipe['ingredients']:
#              greek.add(ingredient)
#     if recipe['cuisine'] == 'indian':
#         for ingredient in recipe['ingredients']:
#              indian.add(ingredient)
#     if recipe['cuisine'] == 'brazilian':
#         for ingredient in recipe['ingredients']:
#              brazilian.add(ingredient)
#     if recipe['cuisine'] == 'french':
#         for ingredient in recipe['ingredients']:
#              french.add(ingredient)
#     if recipe['cuisine'] == 'irish':
#         for ingredient in recipe['ingredients']:
#              irish.add(ingredient)
#     if recipe['cuisine'] == 'chinese':
#         for ingredient in recipe['ingredients']:
#              chinese.add(ingredient)
#     if recipe['cuisine'] == 'thai':
#         for ingredient in recipe['ingredients']:
#              thai.add(ingredient)
#     if recipe['cuisine'] == 'russian':
#         for ingredient in recipe['ingredients']:
#              russian.add(ingredient)
#     if recipe['cuisine'] == 'korean':
#         for ingredient in recipe['ingredients']:
#              korean.add(ingredient)
#     if recipe['cuisine'] == 'southern_us':
#         for ingredient in recipe['ingredients']:
#              southern_us.add(ingredient)
#     if recipe['cuisine'] == 'filipino':
#         for ingredient in recipe['ingredients']:
#              filipino.add(ingredient)
#     if recipe['cuisine'] == 'vietnamese':
#         for ingredient in recipe['ingredients']:
#              vietnamese.add(ingredient)
#     if recipe['cuisine'] == 'japanese':
#         for ingredient in recipe['ingredients']:
#              japanese.add(ingredient)
#     if recipe['cuisine'] == 'cajun_creole':
#         for ingredient in recipe['ingredients']:
#              cajun_creole.add(ingredient)
#     if recipe['cuisine'] == 'moroccan':
#         for ingredient in recipe['ingredients']:
#              moroccan.add(ingredient)
#     if recipe['cuisine'] == 'british':
#         for ingredient in recipe['ingredients']:
#              british.add(ingredient)
#     if recipe['cuisine'] == 'jamaican':
#         for ingredient in recipe['ingredients']:
#              jamaican.add(ingredient)
#     if recipe['cuisine'] == 'spanish':
#         for ingredient in recipe['ingredients']:
#              spanish.add(ingredient)
#     if recipe['cuisine'] == 'mexican':
#         for ingredient in recipe['ingredients']:
#              mexican.add(ingredient)

# %%
for recipe in tr:
    if recipe['cuisine'] == 'italian':
        for ingredient in recipe['ingredients']:
             italian.add(ingredient)
    if recipe['cuisine'] == 'greek':
        for ingredient in recipe['ingredients']:
             greek.add(ingredient)
    if recipe['cuisine'] == 'indian':
        for ingredient in recipe['ingredients']:
             indian.add(ingredient)
    if recipe['cuisine'] == 'brazilian':
        for ingredient in recipe['ingredients']:
             brazilian.add(ingredient)
    if recipe['cuisine'] == 'french':
        for ingredient in recipe['ingredients']:
             french.add(ingredient)
    if recipe['cuisine'] == 'irish':
        for ingredient in recipe['ingredients']:
             irish.add(ingredient)
    if recipe['cuisine'] == 'chinese':
        for ingredient in recipe['ingredients']:
             chinese.add(ingredient)
    if recipe['cuisine'] == 'thai':
        for ingredient in recipe['ingredients']:
             thai.add(ingredient)
    if recipe['cuisine'] == 'russian':
        for ingredient in recipe['ingredients']:
             russian.add(ingredient)
    if recipe['cuisine'] == 'korean':
        for ingredient in recipe['ingredients']:
             korean.add(ingredient)
    if recipe['cuisine'] == 'southern_us':
        for ingredient in recipe['ingredients']:
             southern_us.add(ingredient)
    if recipe['cuisine'] == 'filipino':
        for ingredient in recipe['ingredients']:
             filipino.add(ingredient)
    if recipe['cuisine'] == 'vietnamese':
        for ingredient in recipe['ingredients']:
             vietnamese.add(ingredient)
    if recipe['cuisine'] == 'japanese':
        for ingredient in recipe['ingredients']:
             japanese.add(ingredient)
    if recipe['cuisine'] == 'cajun_creole':
        for ingredient in recipe['ingredients']:
             cajun_creole.add(ingredient)
    if recipe['cuisine'] == 'moroccan':
        for ingredient in recipe['ingredients']:
             moroccan.add(ingredient)
    if recipe['cuisine'] == 'british':
        for ingredient in recipe['ingredients']:
             british.add(ingredient)
    if recipe['cuisine'] == 'jamaican':
        for ingredient in recipe['ingredients']:
             jamaican.add(ingredient)
    if recipe['cuisine'] == 'spanish':
        for ingredient in recipe['ingredients']:
             spanish.add(ingredient)
    if recipe['cuisine'] == 'mexican':
        for ingredient in recipe['ingredients']:
             mexican.add(ingredient)

# %%
for cuisine in cuisines:
    print(f"    if cuisine == '{cuisine}':")
    print("        for cuisine in cuisines:")
    print(f"            if cuisine != '{cuisine}':")
    print(f"                {cuisine} = {cuisine}.difference(eval(cuisine))")
# Out:
#     if cuisine == 'italian':
#         for cuisine in cuisines:
#             if cuisine != 'italian':
#                 italian = italian.difference(eval(cuisine))
#     if cuisine == 'greek':
#         for cuisine in cuisines:
#             if cuisine != 'greek':
#                 greek = greek.difference(eval(cuisine))
#     if cuisine == 'indian':
#         for cuisine in cuisines:
#             if cuisine != 'indian':
#                 indian = indian.difference(eval(cuisine))
#     if cuisine == 'brazilian':
#         for cuisine in cuisines:
#             if cuisine != 'brazilian':
#                 brazilian = brazilian.difference(eval(cuisine))
#     if cuisine == 'french':
#         for cuisine in cuisines:
#             if cuisine != 'french':
#                 french = french.difference(eval(cuisine))
#     if cuisine == 'chinese':
#         for cuisine in cuisines:
#             if cuisine != 'chinese':
#                 chinese = chinese.difference(eval(cuisine))
#     if cuisine == 'thai':
#         for cuisine in cuisines:
#             if cuisine != 'thai':
#                 thai = thai.difference(eval(cuisine))
#     if cuisine == 'russian':
#         for cuisine in cuisines:
#             if cuisine != 'russian':
#                 russian = russian.difference(eval(cuisine))
#     if cuisine == 'korean':
#         for cuisine in cuisines:
#             if cuisine != 'korean':
#                 korean = korean.difference(eval(cuisine))
#     if cuisine == 'southern_us':
#         for cuisine in cuisines:
#             if cuisine != 'southern_us':
#                 southern_us = southern_us.difference(eval(cuisine))
#     if cuisine == 'filipino':
#         for cuisine in cuisines:
#             if cuisine != 'filipino':
#                 filipino = filipino.difference(eval(cuisine))
#     if cuisine == 'vietnamese':
#         for cuisine in cuisines:
#             if cuisine != 'vietnamese':
#                 vietnamese = vietnamese.difference(eval(cuisine))
#     if cuisine == 'japanese':
#         for cuisine in cuisines:
#             if cuisine != 'japanese':
#                 japanese = japanese.difference(eval(cuisine))
#     if cuisine == 'cajun_creole':
#         for cuisine in cuisines:
#             if cuisine != 'cajun_creole':
#                 cajun_creole = cajun_creole.difference(eval(cuisine))
#     if cuisine == 'moroccan':
#         for cuisine in cuisines:
#             if cuisine != 'moroccan':
#                 moroccan = moroccan.difference(eval(cuisine))
#     if cuisine == 'british':
#         for cuisine in cuisines:
#             if cuisine != 'british':
#                 british = british.difference(eval(cuisine))
#     if cuisine == 'jamaican':
#         for cuisine in cuisines:
#             if cuisine != 'jamaican':
#                 jamaican = jamaican.difference(eval(cuisine))
#     if cuisine == 'spanish':
#         for cuisine in cuisines:
#             if cuisine != 'spanish':
#                 spanish = spanish.difference(eval(cuisine))
#     if cuisine == 'mexican':
#         for cuisine in cuisines:
#             if cuisine != 'mexican':
#                 mexican = mexican.difference(eval(cuisine))

# %%
for cuisine in cuisines:
    if cuisine == 'italian':
        for cuisine in cuisines:
            if cuisine != 'italian':
                italian = italian.difference(eval(cuisine))
    if cuisine == 'greek':
        for cuisine in cuisines:
            if cuisine != 'greek':
                greek = greek.difference(eval(cuisine))
    if cuisine == 'indian':
        for cuisine in cuisines:
            if cuisine != 'indian':
                indian = indian.difference(eval(cuisine))
    if cuisine == 'brazilian':
        for cuisine in cuisines:
            if cuisine != 'brazilian':
                brazilian = brazilian.difference(eval(cuisine))
    if cuisine == 'french':
        for cuisine in cuisines:
            if cuisine != 'french':
                french = french.difference(eval(cuisine))
    if cuisine == 'chinese':
        for cuisine in cuisines:
            if cuisine != 'chinese':
                chinese = chinese.difference(eval(cuisine))
    if cuisine == 'thai':
        for cuisine in cuisines:
            if cuisine != 'thai':
                thai = thai.difference(eval(cuisine))
    if cuisine == 'russian':
        for cuisine in cuisines:
            if cuisine != 'russian':
                russian = russian.difference(eval(cuisine))
    if cuisine == 'korean':
        for cuisine in cuisines:
            if cuisine != 'korean':
                korean = korean.difference(eval(cuisine))
    if cuisine == 'southern_us':
        for cuisine in cuisines:
            if cuisine != 'southern_us':
                southern_us = southern_us.difference(eval(cuisine))
    if cuisine == 'filipino':
        for cuisine in cuisines:
            if cuisine != 'filipino':
                filipino = filipino.difference(eval(cuisine))
    if cuisine == 'vietnamese':
        for cuisine in cuisines:
            if cuisine != 'vietnamese':
                vietnamese = vietnamese.difference(eval(cuisine))
    if cuisine == 'japanese':
        for cuisine in cuisines:
            if cuisine != 'japanese':
                japanese = japanese.difference(eval(cuisine))
    if cuisine == 'cajun_creole':
        for cuisine in cuisines:
            if cuisine != 'cajun_creole':
                cajun_creole = cajun_creole.difference(eval(cuisine))
    if cuisine == 'moroccan':
        for cuisine in cuisines:
            if cuisine != 'moroccan':
                moroccan = moroccan.difference(eval(cuisine))
    if cuisine == 'british':
        for cuisine in cuisines:
            if cuisine != 'british':
                british = british.difference(eval(cuisine))
    if cuisine == 'jamaican':
        for cuisine in cuisines:
            if cuisine != 'jamaican':
                jamaican = jamaican.difference(eval(cuisine))
    if cuisine == 'spanish':
        for cuisine in cuisines:
            if cuisine != 'spanish':
                spanish = spanish.difference(eval(cuisine))
    if cuisine == 'mexican':
        for cuisine in cuisines:
            if cuisine != 'mexican':
                mexican = mexican.difference(eval(cuisine))

# %%
for cuisine in cuisines:
    print(f'ingredients unique to {cuisine}: {len(eval(cuisine))}')
# Out:
# ingredients unique to italian: 485
# ingredients unique to greek: 93
# ingredients unique to indian: 186
# ingredients unique to brazilian: 73
# ingredients unique to french: 323
# ingredients unique to chinese: 256
# ingredients unique to thai: 144
# ingredients unique to russian: 87
# ingredients unique to korean: 95
# ingredients unique to southern_us: 638
# ingredients unique to filipino: 137
# ingredients unique to vietnamese: 226
# ingredients unique to japanese: 525
# ingredients unique to cajun_creole: 527
# ingredients unique to moroccan: 237
# ingredients unique to british: 497
# ingredients unique to jamaican: 358
# ingredients unique to spanish: 1263
# ingredients unique to mexican: 528

# %%
tr2 = tr.copy()

for recipe in tr2:
    for cuisine in cuisines:
        if recipe['cuisine'] == cuisine:
            recipe['ingredients'] = list(set(recipe['ingredients']).intersection(eval(cuisine)))

# %%
common = 0
unique = 0
for recipe in tr2:
    if len(recipe['ingredients']) == 0:
        common += 1
    else:
        unique += 1

print(f'common: {common}')
print(f'unique: {unique}')
# Out:
# common: 27993
# unique: 11781

# %%
alia = []

for recipe in tr:
    for x in recipe['ingredients']:
        alia.append(x)

# %%
pd.Series(alia).value_counts(ascending = False).head(20)
# Out:
# salt                   18049
# onions                  7972
# olive oil               7972
# water                   7457
# garlic                  7380
# sugar                   6434
# garlic cloves           6237
# butter                  4848
# ground black pepper     4785
# all-purpose flour       4632
# pepper                  4438
# vegetable oil           4385
# eggs                    3388
# soy sauce               3296
# kosher salt             3113
# green onions            3078
# tomatoes                3058
# large eggs              2948
# carrots                 2814
# unsalted butter         2782
# dtype: int64

# %%
x = 0
for recipe in tr:
    if len(recipe['ingredients']) <= 2:
        print(recipe)
# Out:
# {'id': 17004, 'cuisine': 'korean', 'ingredients': ['water', 'barley']}
# {'id': 29853, 'cuisine': 'mexican', 'ingredients': ['granulated sugar', 'large egg whites']}
# {'id': 8304, 'cuisine': 'italian', 'ingredients': ['aged gouda', 'soppressata']}
# {'id': 4734, 'cuisine': 'japanese', 'ingredients': ['sushi rice']}
# {'id': 36852, 'cuisine': 'italian', 'ingredients': ['melted butter', 'potatoes']}
# {'id': 30297, 'cuisine': 'korean', 'ingredients': ['water', 'medium-grain rice']}
# {'id': 5161, 'cuisine': 'french', 'ingredients': ['baton', 'croissant dough']}
# {'id': 40913, 'cuisine': 'southern_us', 'ingredients': ['honey', 'tomatoes']}
# {'id': 42490, 'cuisine': 'brazilian', 'ingredients': ['muenster cheese', 'cream cheese']}
# {'id': 46716, 'cuisine': 'chinese', 'ingredients': ['long-grain rice', 'cold water']}
# {'id': 42120, 'cuisine': 'french', 'ingredients': ['milk', 'coffee']}
# {'id': 35808, 'cuisine': 'french', 'ingredients': ['brown sugar', 'vanilla beans']}
# {'id': 48831, 'cuisine': 'mexican', 'ingredients': ['onions', 'Hatch Green Chiles']}
# {'id': 39581, 'cuisine': 'mexican', 'ingredients': ['water', 'flour']}
# {'id': 21841, 'cuisine': 'chinese', 'ingredients': ['cooked rice', 'skinless chicken breasts']}
# {'id': 11734, 'cuisine': 'french', 'ingredients': ['large egg whites', 'sugar']}
# {'id': 7833, 'cuisine': 'vietnamese', 'ingredients': ['dried rice noodles']}
# {'id': 38171, 'cuisine': 'italian', 'ingredients': ['dough', 'all-purpose flour']}
# {'id': 39296, 'cuisine': 'greek', 'ingredients': ['coffee', 'sugar']}
# {'id': 7752, 'cuisine': 'cajun_creole', 'ingredients': ['asparagus', 'cajun seasoning']}
# {'id': 42352, 'cuisine': 'vietnamese', 'ingredients': ['roast', 'sweetened condensed milk']}
# {'id': 29568, 'cuisine': 'italian', 'ingredients': ['chocolate', 'orange soda']}
# {'id': 43207, 'cuisine': 'french', 'ingredients': ['heavy cream', 'chocolate']}
# {'id': 23751, 'cuisine': 'indian', 'ingredients': ['plain low-fat yogurt', 'brown sugar']}
# {'id': 16070, 'cuisine': 'spanish', 'ingredients': ['quince paste', 'manchego cheese']}
# {'id': 15453, 'cuisine': 'italian', 'ingredients': ['garlic', 'olive oil']}
# {'id': 16752, 'cuisine': 'japanese', 'ingredients': ['short-grain rice', 'cold water']}
# {'id': 47053, 'cuisine': 'brazilian', 'ingredients': ['cocoa powder', 'condensed milk']}
# {'id': 2444, 'cuisine': 'southern_us', 'ingredients': ['greens', 'kosher salt']}
# {'id': 1054, 'cuisine': 'southern_us', 'ingredients': ['large eggs', 'frozen mixed vegetables']}
# {'id': 4096, 'cuisine': 'southern_us', 'ingredients': ['dark brown sugar', 'bacon slices']}
# {'id': 39510, 'cuisine': 'cajun_creole', 'ingredients': ['vegetable oil', 'flour']}
# {'id': 32030, 'cuisine': 'indian', 'ingredients': ['lemon juice', 'whole milk']}
# {'id': 28248, 'cuisine': 'japanese', 'ingredients': ['kelp', 'cold water']}
# {'id': 28983, 'cuisine': 'mexican', 'ingredients': ['grated parmesan cheese', 'angel hair']}
# {'id': 16814, 'cuisine': 'mexican', 'ingredients': ['enchilada sauce', 'chicken']}
# {'id': 43312, 'cuisine': 'japanese', 'ingredients': ['water', 'short-grain rice']}
# {'id': 25360, 'cuisine': 'southern_us', 'ingredients': ['baking soda', 'cream of tartar']}
# {'id': 41116, 'cuisine': 'japanese', 'ingredients': ['rice', 'Spring! Water']}
# {'id': 41211, 'cuisine': 'italian', 'ingredients': ['cooking spray', 'baguette']}
# {'id': 4203, 'cuisine': 'italian', 'ingredients': ['Chianti', 'navel oranges']}
# {'id': 9488, 'cuisine': 'indian', 'ingredients': ['fresh lemon juice', 'whole milk']}
# {'id': 19766, 'cuisine': 'spanish', 'ingredients': ['bacon', 'medjool date']}
# {'id': 25440, 'cuisine': 'southern_us', 'ingredients': ['country ham', 'coca-cola']}
# {'id': 5729, 'cuisine': 'chinese', 'ingredients': ['salt', 'szechwan peppercorns']}
# {'id': 19588, 'cuisine': 'cajun_creole', 'ingredients': ['water', 'coffee']}
# {'id': 5423, 'cuisine': 'russian', 'ingredients': ['prepared horseradish', 'beets']}
# {'id': 6220, 'cuisine': 'french', 'ingredients': ['raspberries', 'sugar']}
# {'id': 4173, 'cuisine': 'southern_us', 'ingredients': ['butter', 'jam']}
# {'id': 36818, 'cuisine': 'indian', 'ingredients': ['plain low-fat yogurt']}
# {'id': 19772, 'cuisine': 'indian', 'ingredients': ['unsalted butter']}
# {'id': 27614, 'cuisine': 'mexican', 'ingredients': ['pozole', 'pork']}
# {'id': 42298, 'cuisine': 'italian', 'ingredients': ['all-purpose flour', 'dough']}
# {'id': 16116, 'cuisine': 'japanese', 'ingredients': ['udon']}
# {'id': 3883, 'cuisine': 'chinese', 'ingredients': ['hot red pepper flakes', 'peanut oil']}
# {'id': 29738, 'cuisine': 'thai', 'ingredients': ['sticky rice']}
# {'id': 41124, 'cuisine': 'indian', 'ingredients': ['butter']}
# {'id': 11023, 'cuisine': 'vietnamese', 'ingredients': ['greek style plain yogurt', 'sweetened condensed milk']}
# {'id': 2691, 'cuisine': 'italian', 'ingredients': ['parmigiano reggiano cheese', 'fennel bulb']}
# {'id': 32345, 'cuisine': 'french', 'ingredients': ['sugar', 'pink grapefruit juice']}
# {'id': 18877, 'cuisine': 'french', 'ingredients': ['large eggs', 'bread']}
# {'id': 38051, 'cuisine': 'italian', 'ingredients': ['country bread', 'garlic']}
# {'id': 15850, 'cuisine': 'british', 'ingredients': ['milk chocolate', 'Crispy Rice Cereal']}
# {'id': 45695, 'cuisine': 'french', 'ingredients': ['sour cream', 'whipping cream']}
# {'id': 1187, 'cuisine': 'southern_us', 'ingredients': ['pork spare ribs', 'kosher salt']}
# {'id': 40899, 'cuisine': 'indian', 'ingredients': ['coconut', 'water']}
# {'id': 32631, 'cuisine': 'mexican', 'ingredients': ['corn tortillas']}
# {'id': 39185, 'cuisine': 'italian', 'ingredients': ['water', 'polenta']}
# {'id': 15301, 'cuisine': 'italian', 'ingredients': ['challa', 'semisweet chocolate']}
# {'id': 10236, 'cuisine': 'indian', 'ingredients': ['vegetable oil', 'pappadams']}
# {'id': 26141, 'cuisine': 'mexican', 'ingredients': ['hot water', 'masa harina']}
# {'id': 42489, 'cuisine': 'filipino', 'ingredients': ['coconut', 'warm water']}
# {'id': 26399, 'cuisine': 'mexican', 'ingredients': ['mojo marinade', 'boneless chicken skinless thigh']}
# {'id': 45472, 'cuisine': 'brazilian', 'ingredients': ['juice', 'frozen strawberries']}
# {'id': 13540, 'cuisine': 'chinese', 'ingredients': ['peanut oil', 'szechwan peppercorns']}
# {'id': 31865, 'cuisine': 'thai', 'ingredients': ['jalapeno chilies', 'vinegar']}
# {'id': 4784, 'cuisine': 'vietnamese', 'ingredients': ['canola oil', 'shallots']}
# {'id': 29570, 'cuisine': 'thai', 'ingredients': ['grained']}
# {'id': 39070, 'cuisine': 'italian', 'ingredients': ['lemon', 'artichokes']}
# {'id': 30280, 'cuisine': 'french', 'ingredients': ['whipping cream', 'chocolate baking bar']}
# {'id': 33175, 'cuisine': 'french', 'ingredients': ['parmigiano reggiano cheese', 'frozen pastry puff sheets']}
# {'id': 39740, 'cuisine': 'italian', 'ingredients': ['baguette', 'extra-virgin olive oil']}
# {'id': 47231, 'cuisine': 'southern_us', 'ingredients': ['salt', 'pork shoulder roast']}
# {'id': 34105, 'cuisine': 'irish', 'ingredients': ['champagne', 'stout']}
# {'id': 9632, 'cuisine': 'jamaican', 'ingredients': ['chicken', 'jerk marinade']}
# {'id': 20613, 'cuisine': 'mexican', 'ingredients': ['barbecue sauce', 'ranch dressing']}
# {'id': 22237, 'cuisine': 'chinese', 'ingredients': ['peanut oil', 'onions']}
# {'id': 22444, 'cuisine': 'cajun_creole', 'ingredients': ['creole mustard', 'apple butter']}
# {'id': 10443, 'cuisine': 'vietnamese', 'ingredients': ['shrimp chips', 'corn oil']}
# {'id': 28087, 'cuisine': 'southern_us', 'ingredients': ['bourbon whiskey', 'bacon grease']}
# {'id': 25601, 'cuisine': 'italian', 'ingredients': ['garlic', 'extra-virgin olive oil']}
# {'id': 1710, 'cuisine': 'french', 'ingredients': ['sugar', 'puff pastry']}
# {'id': 33031, 'cuisine': 'chinese', 'ingredients': ['salt', 'long grain white rice']}
# {'id': 25820, 'cuisine': 'italian', 'ingredients': ['melon', 'prosciutto']}
# {'id': 4314, 'cuisine': 'mexican', 'ingredients': ['tamarind', 'large shrimp']}
# {'id': 44706, 'cuisine': 'korean', 'ingredients': ['medium-grain rice', 'cold water']}
# {'id': 1306, 'cuisine': 'southern_us', 'ingredients': ['cake batter', 'pecans']}
# {'id': 29206, 'cuisine': 'french', 'ingredients': ['cognac', 'marzipan']}
# {'id': 1794, 'cuisine': 'spanish', 'ingredients': ['baking potatoes', 'extra-virgin olive oil']}
# {'id': 25517, 'cuisine': 'japanese', 'ingredients': ['konbu', 'dried bonito flakes']}
# {'id': 29849, 'cuisine': 'southern_us', 'ingredients': ['lemonade concentrate']}
# {'id': 40216, 'cuisine': 'french', 'ingredients': ['pastry', 'dough']}
# {'id': 33045, 'cuisine': 'spanish', 'ingredients': ['manchego cheese', 'quince paste']}
# {'id': 39186, 'cuisine': 'thai', 'ingredients': ['jasmine rice']}
# {'id': 39799, 'cuisine': 'vietnamese', 'ingredients': ['coffee', 'sweetened condensed milk']}
# {'id': 39127, 'cuisine': 'southern_us', 'ingredients': ['chicken breasts', 'barbecue sauce']}
# {'id': 7540, 'cuisine': 'cajun_creole', 'ingredients': ['vegetable oil', 'all-purpose flour']}
# {'id': 30121, 'cuisine': 'french', 'ingredients': ['white wine', 'cassis liqueur']}
# {'id': 952, 'cuisine': 'greek', 'ingredients': ['plain yogurt', 'milk']}
# {'id': 14335, 'cuisine': 'indian', 'ingredients': ['unsalted butter']}
# {'id': 32610, 'cuisine': 'chinese', 'ingredients': ['water', 'long grain white rice']}
# {'id': 29092, 'cuisine': 'italian', 'ingredients': ['prosciutto', 'cantaloupe']}
# {'id': 32021, 'cuisine': 'italian', 'ingredients': ['fresh parsley', 'chicken breasts']}
# {'id': 20854, 'cuisine': 'southern_us', 'ingredients': ['sugar', 'peaches in heavy syrup']}
# {'id': 40583, 'cuisine': 'vietnamese', 'ingredients': ['meat', 'frozen banana leaf']}
# {'id': 46442, 'cuisine': 'french', 'ingredients': ['ice water', 'apples']}
# {'id': 47395, 'cuisine': 'mexican', 'ingredients': ['boneless skinless chicken breasts', 'picante sauce']}
# {'id': 11771, 'cuisine': 'french', 'ingredients': ['whipping cream', 'buttermilk']}
# {'id': 11780, 'cuisine': 'italian', 'ingredients': ['aged balsamic vinegar', 'parmigiano reggiano cheese']}
# {'id': 18869, 'cuisine': 'indian', 'ingredients': ['chicken', 'chicken breasts']}
# {'id': 21949, 'cuisine': 'french', 'ingredients': ['buttermilk', 'whipping cream']}
# {'id': 15677, 'cuisine': 'southern_us', 'ingredients': ['butter', 'bacon']}
# {'id': 39221, 'cuisine': 'italian', 'ingredients': ['cherry tomatoes']}
# {'id': 24431, 'cuisine': 'moroccan', 'ingredients': ['meyer lemon', 'kosher salt']}
# {'id': 18514, 'cuisine': 'mexican', 'ingredients': ['salsa', 'boneless skinless chicken breasts']}
# {'id': 41135, 'cuisine': 'french', 'ingredients': ['butter']}
# {'id': 21836, 'cuisine': 'french', 'ingredients': ['sour cream', 'heavy cream']}
# {'id': 36874, 'cuisine': 'indian', 'ingredients': ['cumin seed']}
# {'id': 26525, 'cuisine': 'southern_us', 'ingredients': ['hot water', 'self-rising cornmeal']}
# {'id': 4628, 'cuisine': 'japanese', 'ingredients': ['bonito flakes', 'konbu']}
# {'id': 38303, 'cuisine': 'southern_us', 'ingredients': ['chile paste', 'corn husks']}
# {'id': 15180, 'cuisine': 'chinese', 'ingredients': ['water', 'black rice']}
# {'id': 16722, 'cuisine': 'italian', 'ingredients': ['pepper', 'salt']}
# {'id': 35028, 'cuisine': 'french', 'ingredients': ['haricots verts']}
# {'id': 39809, 'cuisine': 'japanese', 'ingredients': ['konbu', 'bonito flakes']}
# {'id': 17840, 'cuisine': 'cajun_creole', 'ingredients': ['all-purpose flour', 'vegetable oil']}
# {'id': 43721, 'cuisine': 'irish', 'ingredients': ['vegetable oil', 'irish bacon']}
# {'id': 30060, 'cuisine': 'indian', 'ingredients': ['whole milk', 'lime']}
# {'id': 27231, 'cuisine': 'korean', 'ingredients': ['beef', 'meat']}
# {'id': 35819, 'cuisine': 'french', 'ingredients': ['fresh lemon juice', 'artichokes']}
# {'id': 2391, 'cuisine': 'french', 'ingredients': ['unsalted butter', 'baking potatoes']}
# {'id': 10536, 'cuisine': 'japanese', 'ingredients': ['sea salt', 'frozen edamame beans']}
# {'id': 39559, 'cuisine': 'italian', 'ingredients': ['artichokes', 'lemon']}
# {'id': 42055, 'cuisine': 'mexican', 'ingredients': ['buttermilk', 'whipping cream']}
# {'id': 44850, 'cuisine': 'vietnamese', 'ingredients': ['shallots', 'canola oil']}
# {'id': 10445, 'cuisine': 'french', 'ingredients': ['hollandaise sauce', 'fresh lemon juice']}
# {'id': 46116, 'cuisine': 'italian', 'ingredients': ['olive oil', 'crushed tomatoes']}
# {'id': 29224, 'cuisine': 'italian', 'ingredients': ['prosciutto', 'fresh mozzarella balls']}
# {'id': 24685, 'cuisine': 'mexican', 'ingredients': ['masa harina', 'kosher salt']}
# {'id': 18593, 'cuisine': 'mexican', 'ingredients': ['vegetable oil']}
# {'id': 5513, 'cuisine': 'mexican', 'ingredients': ['masa harina', 'water']}
# {'id': 41620, 'cuisine': 'italian', 'ingredients': ['melon', 'prosciutto']}
# {'id': 7303, 'cuisine': 'cajun_creole', 'ingredients': ['cinnamon rolls', 'sugar']}
# {'id': 911, 'cuisine': 'french', 'ingredients': ['vegetable oil', 'baking potatoes']}
# {'id': 18807, 'cuisine': 'italian', 'ingredients': ['olive oil', 'roma tomatoes']}
# {'id': 27884, 'cuisine': 'spanish', 'ingredients': ['sherry vinegar', 'light brown sugar']}
# {'id': 3951, 'cuisine': 'korean', 'ingredients': ['short rib', 'scallions']}
# {'id': 11689, 'cuisine': 'french', 'ingredients': ['sour cream', 'heavy cream']}
# {'id': 47067, 'cuisine': 'italian', 'ingredients': ['parmesan cheese', 'vegetable oil cooking spray']}
# {'id': 31260, 'cuisine': 'vietnamese', 'ingredients': ['ground coffee', 'sweetened condensed milk']}
# {'id': 40407, 'cuisine': 'southern_us', 'ingredients': ['cheese', 'refrigerated crescent rolls']}
# {'id': 22577, 'cuisine': 'indian', 'ingredients': ['chickpeas', 'basmati rice']}
# {'id': 26100, 'cuisine': 'italian', 'ingredients': ['eggs', 'all-purpose flour']}
# {'id': 23380, 'cuisine': 'french', 'ingredients': ['semi-sweet chocolate morsels', 'refrigerated crescent rolls']}
# {'id': 7460, 'cuisine': 'spanish', 'ingredients': ['spanish chorizo']}
# {'id': 29758, 'cuisine': 'italian', 'ingredients': ['durum wheat flour', 'semolina flour']}
# {'id': 20294, 'cuisine': 'japanese', 'ingredients': ['konbu', 'dried bonito flakes']}
# {'id': 24255, 'cuisine': 'greek', 'ingredients': ['2% reduced-fat milk', 'greek style plain yogurt']}
# {'id': 20420, 'cuisine': 'italian', 'ingredients': ['vanilla ice cream', 'brewed espresso']}
# {'id': 6638, 'cuisine': 'french', 'ingredients': ['buttermilk', 'heavy whipping cream']}
# {'id': 20570, 'cuisine': 'filipino', 'ingredients': ['water', 'sago pearls']}
# {'id': 32772, 'cuisine': 'spanish', 'ingredients': ['sweetened condensed milk']}
# {'id': 33158, 'cuisine': 'french', 'ingredients': ['haricots verts', 'unsalted butter']}
# {'id': 1863, 'cuisine': 'italian', 'ingredients': ['vegetable oil cooking spray', 'parmesan cheese']}
# {'id': 13122, 'cuisine': 'mexican', 'ingredients': ['water', 'mexican chocolate']}
# {'id': 12805, 'cuisine': 'japanese', 'ingredients': ['water']}
# {'id': 38822, 'cuisine': 'japanese', 'ingredients': ['water', 'dashi kombu']}
# {'id': 16143, 'cuisine': 'southern_us', 'ingredients': ['yellow corn meal', 'refrigerated piecrusts']}
# {'id': 15448, 'cuisine': 'japanese', 'ingredients': ['white rice', 'water']}
# {'id': 23237, 'cuisine': 'indian', 'ingredients': ['tandoori paste', 'shoulder lamb chops']}
# {'id': 24072, 'cuisine': 'french', 'ingredients': ['strawberry ice cream', 'sorbet']}
# {'id': 27939, 'cuisine': 'southern_us', 'ingredients': ['muscadine grapes', 'water']}
# {'id': 21024, 'cuisine': 'vietnamese', 'ingredients': ['garlic cloves', 'olive oil']}
# {'id': 48090, 'cuisine': 'southern_us', 'ingredients': ['pie filling', 'sparkling sugar']}
# {'id': 49693, 'cuisine': 'french', 'ingredients': ['crescent rolls', 'Nutella']}
# {'id': 30923, 'cuisine': 'japanese', 'ingredients': ['bonito', 'konbu']}
# {'id': 10816, 'cuisine': 'greek', 'ingredients': ['phyllo']}
# {'id': 29162, 'cuisine': 'chinese', 'ingredients': ['long-grain rice', 'water']}
# {'id': 199, 'cuisine': 'indian', 'ingredients': ['fresh lemon juice', 'whole milk']}
# {'id': 37839, 'cuisine': 'italian', 'ingredients': ['salad dressing', 'boneless skinless chicken breast halves']}
# {'id': 23182, 'cuisine': 'british', 'ingredients': ['cream', 'coffee']}
# {'id': 23918, 'cuisine': 'french', 'ingredients': ['sugar', 'almonds']}
# {'id': 9778, 'cuisine': 'mexican', 'ingredients': ['vegetable oil', 'corn tortillas']}
# {'id': 16618, 'cuisine': 'indian', 'ingredients': ['wafer', 'vegetable oil']}
# {'id': 33745, 'cuisine': 'spanish', 'ingredients': ['salt', 'roasted red peppers']}
# {'id': 25597, 'cuisine': 'japanese', 'ingredients': ['wasabi powder', 'soy sauce']}
# {'id': 48181, 'cuisine': 'italian', 'ingredients': ['parmesan cheese', 'all-purpose flour']}
# {'id': 2855, 'cuisine': 'italian', 'ingredients': ['sugar', 'espresso']}
# {'id': 6869, 'cuisine': 'french', 'ingredients': ['semisweet chocolate', 'half & half']}
# {'id': 27192, 'cuisine': 'indian', 'ingredients': ['unsalted butter']}
# {'id': 1213, 'cuisine': 'southern_us', 'ingredients': ['salt', 'peanuts']}
# {'id': 16781, 'cuisine': 'indian', 'ingredients': ['butter', 'tomato ketchup']}
# {'id': 11251, 'cuisine': 'italian', 'ingredients': ['soft-wheat flour', 'large eggs']}
# {'id': 12047, 'cuisine': 'mexican', 'ingredients': ['water', 'masa harina']}
# {'id': 752, 'cuisine': 'italian', 'ingredients': ['prosciutto', 'grissini']}
# {'id': 43056, 'cuisine': 'irish', 'ingredients': ['ale', 'Guinness Beer']}
# {'id': 80, 'cuisine': 'southern_us', 'ingredients': ['peanuts', 'salt']}
# {'id': 24895, 'cuisine': 'mexican', 'ingredients': ['adobo sauce', 'light mayonnaise']}
# {'id': 43353, 'cuisine': 'indian', 'ingredients': ['vegetable oil', 'pappadams']}
# {'id': 45094, 'cuisine': 'french', 'ingredients': ['green beans', 'olive oil']}
# {'id': 19077, 'cuisine': 'vietnamese', 'ingredients': ['shallots', 'salad oil']}
# {'id': 28903, 'cuisine': 'filipino', 'ingredients': ['adobo', 'cooking oil']}
# {'id': 7984, 'cuisine': 'italian', 'ingredients': ['olive oil', 'fresh basil leaves']}
# {'id': 27327, 'cuisine': 'british', 'ingredients': ['puff pastry', 'minced meat']}
# {'id': 10013, 'cuisine': 'mexican', 'ingredients': ['warm water', 'masa']}

# %%
most_common = ['eggs', 'milk', 'chocolate', 'chocolate bars', 'large egg whites', 'dry yeast', 'corn starch', 'heavy cream', 'white sugar', 'vanilla beans', 'vanilla', 'vanilla extract', 'bread yeast', 'active dry yeast', 'instant yeast', 'plain flour', '2% reduced fat milk', 'bread', 'egg yolks', 'large egg yolks', 'whole milk', 'shortening', 'bread flour', 'cake flour', 'oil', 'large eggs', 'brown sugar', 'baking powder', 'sugar', 'coffee', 'ice water', 'all-purpose flour', 'cold water', 'hot water', 'warm water', 'granulated sugar', 'whipping cream', 'self rising flour', 'whole wheat flour', 'table salt', 'kosher salt', 'confectioners sugar', 'boiling water', 'extra-virgin olive oil', 'melted butter', 'garlic', 'lard', 'lemon', 'lemon juice', 'vegetable shortening', 'lime', 'sweetened condensed milk', 'olive oil', 'flour', 'all purpose unbleached flour', 'cocoa powder', 'condensed milk', 'sea salt', 'wheat', 'water', 'salt', 'yeast', 'butter', 'vegetable oil', 'unsalted butter']

# %%
removed = 0
for recipe in tr:
    if len(recipe['ingredients']) <= 4:
        temp = recipe['ingredients']
        for ing in most_common:
            if ing in temp:
                temp.remove(ing)
        if len(temp) == 0:
            removed += 1
            tr.remove(recipe)
    if recipe['ingredients'] == [[]]:
        tr.remove(recipe)
        
print(f'removed: {removed}')
# Out:
# removed: 316
